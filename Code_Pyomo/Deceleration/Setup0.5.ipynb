# %%
import os
os.getcwd() + "/Run_EOMV3_Radau2_Deceleration.ipynb"

Batch_Test_List = [0.5]
TT_array = [0.3,0.5,0.7,0.9,1.0,1.3,1.5,2.0]
Node_array = [20,30]


loops = 1

for TT_arrayi in TT_array:
    for Node_arrayi in Node_array:
        TTi = TT_arrayi
        Ni = Node_arrayi
        batch_test = Batch_Test_List[0]

        if batch_test == 0.5:
            Pi = 2
            V_avgi = 0.5
            Walki = False        

        else:
            pass

        for loop in range(1,loops+1):

            print("batch_test = ",batch_test)
            print("Vavg",V_avgi)

            TT = TTi
            V_avg = V_avgi
            N = Ni
            P = Pi
            Walk = Walki
            try:
                main_name = "V_avg" + str(V_avg) + "_loop" + str(loop) + "_N" + str(N) + "_TT" + str(TT)
                print('*******************************************************')
                print("Busy: "+main_name)
                # %store main_name
                # %store TT
                # %store V_avg
                # %store N
                # %store P
                # %store Walk
                #%run /home/godzilla/Desktop/Zubair/Rev5/BatchRunV3/WALK_EOMV2_BATCH.ipynb
                # %run ~/Zubair/Rev12/Run_EOMV3_Radau2_Deceleration.ipynb 
                print("Done: "+main_name)
            except:
                print("Failed: "+main_name)
                continue
# Out:
# batch_test =  0.5
# Vavg 0.5
# *******************************************************
# Busy: V_avg0.5_loop1_N20_TT0.3
# Stored 'main_name' (str)
# Stored 'TT' (float)
# Stored 'V_avg' (float)
# Stored 'N' (int)
# Stored 'P' (int)
# Stored 'Walk' (bool)
#         <script>
#         function code_toggle() {
#             if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                 $('div.cell.code_cell.rendered.selected div.input').hide();
#             } else {
#                 $('div.cell.code_cell.rendered.selected div.input').show();
#             }y
#
#         }
#         </script>
#     <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Solution: Import Files"></form>
#         <script>
#         function code_toggle() {
#             if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                 $('div.cell.code_cell.rendered.selected div.input').hide();
# ...
